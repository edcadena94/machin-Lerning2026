# %% [markdown]
# # Variables Cualitativas
#
# <img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM.png" width="300"/>
#
# **Materia:** 01PAO26-26 - Python 01
# **Docente:** Elvis David Pachacama
# **Estudiante:** Erick Cadena
# **Fecha:** Julio 2026
#
# **Repositorio:** [https://github.com/edcadena94/machin-Lerning2026]

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)
nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Grado' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Doctorado' 'Grado' 'Doctorado' 'Bachillerato' 'Master' 'Secundaria'
#  'Grado' 'Secundaria' 'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Master' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Master'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Doctorado' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Grado'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Grado' 'Master' 'Secundaria' 'Master' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Doctorado' 'Master' 'Bachillerato' 'Doctorado' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Master' 'Master' 'Bachillerato' 'Grado'
#  'Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Master' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Doctorado' 'Master'
#  'Doctorado' 'Secundaria' 'Doctorado' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Master' 'Grado'
#  'Secundaria' 'Secundaria' 'Doctorado' 'Grado' 'Master' 'Secundaria'
#  'Secundaria' 'Master' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Grado' 'Master' 'Secundaria' 'Doctorado' 'Grado' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Master' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np

estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información
import pandas as pd
import matplotlib.pyplot as plt

# Crear DataFrame
df = pd.DataFrame({'nivel_estudios': nivel_estudios})

# Tabla de frecuencias
frecuencia_pandas = df['nivel_estudios'].value_counts()
print(frecuencia_pandas)
# Out:
# nivel_estudios
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
# Diagrama de barras con pandas
frecuencia_pandas.plot(kind='bar', color='steelblue')
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras con Pandas')
plt.xticks(rotation=45)
plt.show()

# %%
# Diagrama de sectores con pandas
colores = ['red', 'blue', 'orange', 'green', 'cyan']
frecuencia_pandas.plot(kind='pie', colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores con Pandas')
plt.ylabel('')
plt.show()
